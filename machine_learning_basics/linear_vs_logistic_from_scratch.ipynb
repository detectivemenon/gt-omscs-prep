# %% [markdown]
# # Linear vs Logistic Regression (from scratch)
#
# *Starter notebook* — 2025-10-16

# %% [markdown]
# ## Plan
# 1. Generate synthetic data
# 2. Implement linear regression with gradient descent
# 3. Implement logistic regression with gradient descent
# 4. Compare decision boundaries / errors

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: synthetic data
np.random.seed(42)
X = np.random.randn(200, 2)
w_true = np.array([1.2, -0.8])
y_lin = X @ w_true + 0.5*np.random.randn(200)
y_log = (X @ w_true + 0.2*np.random.randn(200) > 0).astype(int)

print('X shape:', X.shape)

# %% [markdown]
# ## TODO: Gradient Descent for Linear Regression

# %%
# def linreg_gd(X, y, lr=0.05, epochs=1000):
#     ...
# return w

# %% [markdown]
# ## TODO: Gradient Descent for Logistic Regression

# %%
# def sigmoid(z):
#     return 1/(1+np.exp(-z))
# def logreg_gd(X, y, lr=0.05, epochs=1000):
#     ...
# return w
