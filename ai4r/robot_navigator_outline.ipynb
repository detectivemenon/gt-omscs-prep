# %% [markdown]
# # Robot Navigator: A* + Localization Outline
#
# *Starter notebook* — 2025-10-16

# %% [markdown]
# ## TODOs
# - Represent a grid world
# - Implement A* search (heuristic: Manhattan distance)
# - (Stretch) Particle filter for localization

# %%
# Grid world placeholder
WIDTH, HEIGHT = 10, 10
start, goal = (0,0), (9,9)
# TODO: obstacles, neighbors, heuristic, A* implementation
