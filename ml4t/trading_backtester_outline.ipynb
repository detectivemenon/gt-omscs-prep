# %% [markdown]
# # Trading Strategy Backtester Outline
#
# *Starter notebook* — 2025-10-16

# %% [markdown]
# ## TODOs
# - Load CSV price data (Date, Close)
# - Compute indicators (SMA/EMA/RSI)
# - Define entry/exit rules
# - Simulate trades and compute returns

# %%
import pandas as pd

# TODO: df = pd.read_csv('prices.csv', parse_dates=['Date']).set_index('Date')
# TODO: compute indicators, backtest function
