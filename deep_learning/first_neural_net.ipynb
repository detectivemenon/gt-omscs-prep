# %% [markdown]
# # First Neural Network (Torch or TF)
#
# *Starter notebook* — 2025-10-16
# Choose one framework and implement a tiny MLP.

# %% [markdown]
# ## PyTorch Skeleton

# %%
import torch, torch.nn as nn, torch.optim as optim

device = 'cuda' if torch.cuda.is_available() else 'cpu'
class MLP(nn.Module):
    def __init__(self, in_dim=2, hidden=16, out_dim=1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden), nn.ReLU(),
            nn.Linear(hidden, out_dim)
        )
    def forward(self, x):
        return self.net(x)

# TODO: create toy dataset, train loop, evaluate
print('Device:', device)

# %% [markdown]
# ## TensorFlow Skeleton

# %%
import tensorflow as tf
from tensorflow import keras

# TODO: build a small Sequential model, compile, and fit on toy data
