# %% [markdown]
# # Simple Sentiment Analyzer Outline
#
# *Starter notebook* — 2025-10-16

# %% [markdown]
# ## Plan
# - Load a small text dataset
# - Tokenize / vectorize (Bag-of-Words or TF-IDF)
# - Train a simple classifier (LogReg or Naive Bayes)
# - Evaluate accuracy

# %%
from collections import Counter

# TODO: load dataset (e.g., two lists: pos_texts, neg_texts)
# TODO: build vocabulary and feature vectors
# TODO: train a basic classifier
